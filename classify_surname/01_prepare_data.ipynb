# %% [markdown]
# # Prepare Data

# %%
import modeling.surname_data as sd

# %%
train_test_stat = sd.save_df_surnames_as_pickle()

# %% [markdown]
# # Check Train/Test Distribution

# %%
train_test_stat
# Out:
#             surname_train  surname_test     ratio
# category
# Arabic               1527           473  0.763500
# Chinese               188            80  0.701493
# Czech                 370           148  0.714286
# Dutch                 217            80  0.730640
# English              2754           914  0.750818
# French                209            68  0.754513
# German                545           179  0.752762
# Greek                 154            49  0.758621
# Irish                 174            58  0.750000
# Italian               540           169  0.761636
# Japanese              751           240  0.757820
# Korean                 73            21  0.776596
# Polish                110            29  0.791367
# Portuguese             60            14  0.810811
# Russian              7014          2394  0.745536
# Scottish               82            18  0.820000
# Spanish               229            69  0.768456
# Vietnamese             58            15  0.794521
