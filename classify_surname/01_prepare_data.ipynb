# %% [markdown]
# # Prepare Data

# %%
import surname_data as sd

# %%
train_test_stat = sd.save_df_surnames_as_pickle()

# %% [markdown]
# # Check Train/Test Distribution

# %%
train_test_stat
# Out:
#             surname_train  surname_test     ratio
# category
# Arabic               1478           521  0.739370
# Chinese               198            70  0.738806
# Czech                 405           114  0.780347
# Dutch                 229            68  0.771044
# English              2723           945  0.742366
# French                221            56  0.797834
# German                551           173  0.761050
# Greek                 148            55  0.729064
# Irish                 174            58  0.750000
# Italian               525           184  0.740480
# Japanese              727           264  0.733602
# Korean                 74            20  0.787234
# Polish                108            31  0.776978
# Portuguese             57            17  0.770270
# Russian              7101          2307  0.754783
# Scottish               77            23  0.770000
# Spanish               207            91  0.694631
# Vietnamese             52            21  0.712329
